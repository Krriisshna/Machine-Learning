# %%
import numpy as np
import time

# %% [markdown]
# # Vectors

# %% [markdown]
# ## Vector Creation

# %%
# NumPy routines which allocate memory and fill arrays with value
a = np.zeros(4)
# here it contain integer 4
print(f"np.zeros(4): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.zeros((4,))
# here it contain tuple with only one value(4)
print(f"np.zeros(4,): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.random.random_sample(4)
# default value 0.0≤x<1.0
print(f"np.random.random_sample(4): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
# Out:
# np.zeros(4): a = [0. 0. 0. 0.], a shape = (4,), a data type = float64
# np.zeros(4,): a = [0. 0. 0. 0.], a shape = (4,), a data type = float64
# np.random.random_sample(4): a = [0.68077595 0.47329351 0.8829827  0.44100474], a shape = (4,), a data type = float64

# %%
# NumPy routines which allocate memory and fill arrays with value but do not accept shape as input argument
a = np.arange(4.)
print(f"np.arange(4.): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.random.rand(4)
print(f"np.random.rand(4): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
# random_sample() and rand() do the same thing
# difference is their argument differ as random_sample() takes a tuple
# Out:
# np.arange(4.): a = [0. 1. 2. 3.], a shape = (4,), a data type = float64
# np.random.rand(4): a = [0.9692194  0.85302152 0.47780386 0.0288033 ], a shape = (4,), a data type = float64

# %%
# NumPy routines which allocate memory and fill with user specified values
a = np.array([5,4,3,2]);  print(f"np.array([5,4,3,2]):  a = {a},     a shape = {a.shape}, a data type = {a.dtype}")
a = np.array([5.,4,3,2]); print(f"np.array([5.,4,3,2]): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
# Out:
# np.array([5,4,3,2]):  a = [5 4 3 2],     a shape = (4,), a data type = int64
# np.array([5.,4,3,2]): a = [5. 4. 3. 2.], a shape = (4,), a data type = float64
